# %%
# MLP for detecting objectivity/subjectivity of a piece of text

# %%
import random
import os
import keras
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
import matplotlib.pyplot as plt
import numpy as np
import sys
import re
import string
from nltk.corpus import stopwords # stopwords: words that don't really have any meaning (for this MLP)
                                  # only there to make things grammatically correct.
                                  # eg. words like 'the', 'for', 'is', etc.
# Out:
# C:\Users\--\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data_path_subj = r"C:\Users\--\Documents\GitHub\fake-news-authentication-platform\subjectivity-dataset\subj.txt" # subjective datasets' file path
data_path_obj = r"C:\Users\--\Documents\GitHub\fake-news-authentication-platform\subjectivity-dataset\obj.txt" # objective datasets' file path

# data_path_subj = os.path.join(os.path.dirname(__file__), 'subjectivity-dataset', 'subj.txt')
# data_path_obj = os.path.join(os.path.dirname(__file__), 'subjectivity-dataset', 'obj.txt')
# not using __file__ because it doesn't work with jupyter

def clean_text(text):
    text = str(text).replace("\n", "") # get rid of all newlines
    exclude = set(string.punctuation) # exclude = string of all punctuations
    text = ''.join(ch for ch in text if ch not in exclude) # we only want words, not punctuation.
    text = text.split(" ") # turn it into a list so that we can iterate over it.
    cleaned_text = [i for i in text if i not in stopwords.words("english")]
    cleaned_text = list(filter(None, cleaned_text)) # get rid of all the empty strings ('') in the list    
    return ' '.join(cleaned_text)

dataset = []

with open(data_path_subj, 'r') as file:
    for line in file:
        dataset.extend([(clean_text(line), 0)]) # 0 is the label for subjective

print(dataset)

raise Exception
        
with open(data_path_obj, 'r') as file:
    for line in file:
        dataset.extend([(clean_text(line), 1)]) # 1 is the label for objective

'''
with open(data_path_subj, 'r') as file:
    rawdata = file.read().split('\n') # file.read() returns a string, but with .split(), we turn it into a list.
    dataset.extend([(e, 0) for e in rawdata]) # 0: subj
with open(data_path_obj, 'r') as file:
    rawdata = file.read().split('\n')
    dataset.extend([(e, 1) for e in rawdata]) # 1: obj
'''

random.shuffle(dataset)
train = int(0.9 * len(dataset)) # use 90% of the data for training...
test = len(dataset) - train # ...and 10% for testing.
train_set = dataset[0: min(train, len(dataset))]
test_set = dataset[(-min(test, len(dataset))-1): -1]

training_set_data = [i[0] for i in train_set] # x_train
training_set_labels = [i[1] for i in train_set] # y_train
testing_set_data = [i[0] for i in test_set] # x_val
testing_set_labels = [i[1] for i in test_set] # y_val

max_words = 5000
batch_size = 256
epochs = 10

# load dataset
x_train, y_train, x_val, y_val = training_set_data, training_set_labels, testing_set_data, testing_set_labels 

# prepare data
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(x_train)
x_train = tokenizer.texts_to_matrix(x_train)
x_val = tokenizer.texts_to_matrix(x_val)
y_train = keras.utils.to_categorical(y_train, 2)
y_val = keras.utils.to_categorical(y_val, 2)
# Out:
# [(['movie', 'begins', 'past', 'young', 'boy', 'named', 'sam', 'attempts', 'save', 'celebi', 'hunter'], 0), (['emerging', 'human', 'psyche', 'showing', 'characteristics', 'abstract', 'expressionism', 'minimalism', 'russian', 'constructivism', 'graffiti', 'removal', 'secured', 'place', 'history', 'modern', 'art', 'created', 'artists', 'unconscious', 'artistic', 'achievements'], 0), (['spurning', 'mothers', 'insistence', 'get', 'life', 'mary', 'thrown', 'house', 'rejected', 'joe', 'expelled', 'school', 'grows', 'larger', 'child'], 0), (['amitabh', 'cant', 'believe', 'board', 'directors', 'mind', 'filled', 'revenge', 'better', 'revenge', 'robbing', 'bank', 'ironic', 'may', 'sound'], 0), (['among', 'others', 'excentricities', 'talks', 'small', 'rock', 'gertrude', 'like', 'alive'], 0), (['gives', 'girls', 'fair', 'chance', 'pulling', 'wool', 'eyes', 'using', 'sexiness', 'poach', 'last', 'vestige', 'common', 'sense', 'dons', 'might'], 0), (['styled', 'vh1s', 'behind', 'music', 'mockumentary', 'profiles', 'rise', 'fall', 'internet', 'startup', 'called', 'icevan', 'com'], 0), (['blue', 'predicament', 'also', 'lacks', 'ability', 'outwardly', 'express', 'emotions'], 0), (['killers', 'clues', 'perversion', 'biblical', 'punishments', 'sins', 'stoning', 'burning', 'decapitation'], 0), (['david', 'painter', 'painters', 'block', 'takes', 'job', 'waiter', 'get', 'inspiration'], 0), (['women', 'craved', 'men', 'wanted'], 0), (['set', 'island', 'coast', 'florida', 'techno', 'rave', 'party', 'attracts', 'diverse', 'group', 'college', 'coeds', 'coast', 'guard', 'officer'], 0), (['lesson', 'learned', 'never', 'never', 'mess', 'gay', 'mafia'], 0), (['theme', 'film', 'simultaneously', 'addresses', 'similarities', 'two', 'factions', 'law', 'crime', 'revealing', 'similarities', 'two', 'brothers'], 0), (['theyre', 'jewish', 'theyre', 'grandmothers', 'theyre', 'lesbians'], 0), (['hes', 'neglecting', 'work', 'carping', 'mom', 'behaving', 'badly', 'toward', 'loyal', 'friend', 'bobbi'], 0), (['going', 'gerrys', 'estranged', 'wife', 'margaret', 'worried', 'daughters', 'safety', 'finds', 'another', 'target', 'race', 'find', 'code'], 0), (['valento', 'feels', 'heat', 'turns', 'table', 'makes', 'dupe', 'one', 'rubs', 'das', 'nose'], 0), (['saigon', '1952', 'beautiful', 'exotic', 'mysterious', 'city', 'caught', 'grips', 'vietnamese', 'war', 'liberation', 'french', 'colonial', 'powers'], 0), (['deep', 'northwest', 'lone', 'ranch', 'tucked', 'away', 'purposefully', 'way', 'find', 'looking'], 0), (['young', 'teenager', 'finds', 'father'], 0), (['life', 'theres', 'silver', 'theres', 'lead', 'says', 'rikki', 'ortega', 'moves', 'king', 'street', '193', 'nglio', 'l', 'east', 'side'], 0), (['games', 'chasing', 'rejecting', 'seducing', 'played', 'economically', 'spiritually', 'depressed', 'hong', 'kong', 'without', 'much', 'gusto'], 0), (['television', 'made', 'famous', 'biggest', 'hits', 'happened', 'screen'], 0), (['jordan', 'mom', 'life', 'long', 'search', 'true', 'faith', 'tries', 'protect', 'child', 'believes', 'injustice'], 0), (['bloody', 'magic', 'story', 'zack', 'eleven', 'year', 'old', 'school', 'boy', 'whos', 'family', 'visited', 'three', 'debt', 'collectors'], 0), (['however', 'jane', 'wendys', '12yearold', 'daughter', 'sees', 'make', 'believe', 'refuses', 'believe', 'tales'], 0), (['called', 'elegant', 'documentary', 'sundance', 'eloquent', 'deeply', 'moving', 'la', 'times', 'toyo', 'miyatake', 'infinite', 'shades', 'gray', 'penetrating', 'portrait', 'photographers', 'search', 'truth', 'beauty', 'world', 'impermanence'], 0), (['straight', 'helicopters', 'action', 'take', 'audiences', 'series', 'aerial', 'adventures'], 0), (['lapp', 'woman', 'anni', 'gives', 'shelter', 'farm'], 0), (['also', 'touches', 'encroachment', 'christianity', 'brought', 'missionaries', 'odds', 'mepes', 'tribal', 'traditional', 'roots'], 0), (['set', 'grisly', 'murders', 'brings', 'fbi', 'agent', 'graham', 'norton', 'retirement', 'puts', 'search', 'atrocious', 'killer', 'fiennes', 'who ...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-41-b6eb28bf7a91> in <module>()
#      24 print(dataset)
#      25
# ---> 26 raise Exception
#      27
#      28 with open(data_path_obj, 'r') as file:
#
# Exception:

# %%
# build model
model = Sequential()

model.add(Dense(512, input_shape=(max_words,)))
model.add(Activation('relu'))

model.add(Dropout(0.26)) # 0.25 is the 'sweet spot'

model.add(Dense(2))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

              # show graph of loss and accuracy

# train model
model_log = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)

# visualise results
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(model_log.history['acc'])
plt.plot(model_log.history['val_acc'])
plt.title('accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(model_log.history['loss'])
plt.plot(model_log.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/10
# 9000/9000 [==============================] - 5s 599us/step - loss: 0.4892 - acc: 0.8263 - val_loss: 0.2936 - val_acc: 0.8900
# Epoch 2/10
# 9000/9000 [==============================] - 5s 503us/step - loss: 0.1937 - acc: 0.9272 - val_loss: 0.2516 - val_acc: 0.8950
# Epoch 3/10
# 9000/9000 [==============================] - 4s 494us/step - loss: 0.1110 - acc: 0.9673 - val_loss: 0.2681 - val_acc: 0.8890
# Epoch 4/10
# 9000/9000 [==============================] - 5s 504us/step - loss: 0.0686 - acc: 0.9837 - val_loss: 0.2875 - val_acc: 0.8920
# Epoch 5/10
# 9000/9000 [==============================] - 5s 510us/step - loss: 0.0436 - acc: 0.9909 - val_loss: 0.3155 - val_acc: 0.8800
# Epoch 6/10
# 9000/9000 [==============================] - 5s 509us/step - loss: 0.0288 - acc: 0.9953 - val_loss: 0.3366 - val_acc: 0.8720
# Epoch 7/10
# 9000/9000 [==============================] - 4s 498us/step - loss: 0.0197 - acc: 0.9972 - val_loss: 0.3547 - val_acc: 0.8680
# Epoch 8/10
# 9000/9000 [==============================] - 5s 512us/step - loss: 0.0143 - acc: 0.9987 - val_loss: 0.3795 - val_acc: 0.8640
# Epoch 9/10
# 9000/9000 [==============================] - 5s 505us/step - loss: 0.0108 - acc: 0.9991 - val_loss: 0.4007 - val_acc: 0.8640
# Epoch 10/10
# 9000/9000 [==============================] - 5s 506us/step - loss: 0.0087 - acc: 0.9994 - val_loss: 0.4166 - val_acc: 0.8640

# %%
# draw confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
import itertools, pickle

classes = ["positive", "negative"]

Y_test = np.argmax(y_val, axis=1) # Convert one-hot to index
y_pred = model.predict(x_val)
y_pred_class = np.argmax(y_pred,axis=1)
cnf_matrix = confusion_matrix(Y_test, y_pred_class)
print(classification_report(Y_test, y_pred_class, target_names=classes))

def plot_confusion_matrix(cm, labels,
                          normalize=True,
                          title='Confusion Matrix (Validation Set)',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        #print('Confusion matrix, without normalization')
        pass

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plt.figure(figsize=(20,10))
plot_confusion_matrix(cnf_matrix, labels=classes)
# Out:
#              precision    recall  f1-score   support
#
#    positive       0.86      0.88      0.87       513
#    negative       0.87      0.85      0.86       487
#
# avg / total       0.87      0.87      0.87      1000
